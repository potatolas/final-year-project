# %%
# %store -r simple_htr_master_call_sequences
# %store -r tensor_kart_master_call_sequences
# %store -r sudoku_robot_master_call_sequences
# %store -r skyfall_master_call_sequences

import utils.utils as utils

simple_htr_master_call_sequences = simple_htr_master_call_sequences
tensor_kart_master_call_sequences = tensor_kart_master_call_sequences
sudoku_robot_master_call_sequences = sudoku_robot_master_call_sequences
skyfall_master_call_sequences = skyfall_master_call_sequences

call_sequences = sudoku_robot_master_call_sequences + simple_htr_master_call_sequences + tensor_kart_master_call_sequences + skyfall_master_call_sequences

# %% [markdown]
# ### 3. Usage Patterns

# %%
method_invocations = []

#get list of all method invocations
for call_sequence in call_sequences:
    for method in call_sequence:
        if(method not in method_invocations):
            method_invocations.append(method)

#save method invocationss as defined MethodCall class into new list
method_invocations_processed = []
for method in method_invocations:
    x = ""
    try:
        x = (method.func.value.value + "." + method.func.attr.value)
    except:
        pass
    try:
        x = (method.func.value.value.value + "." + method.func.value.attr.value + "." + method.func.attr.value)
    except:
        pass
    try:
        x = (method.func.value.value.value.value + "." + method.func.value.value.attr.value + "." + method.func.value.attr.value + "." + method.func.attr.value )
    except:
        pass
    try:
        x = (method.func.value.value.value.value.value + "." + method.func.value.value.value.attr.value + "." + method.func.value.value.attr.value + "." + method.func.value.attr.value + "." + method.func.attr.value )
    except:
        pass
    method_invocations_processed.append(utils.MethodCall(x, method))

#save method in call seqeunces as defined MethodCall class into new list
call_sequences_processed = []
for call_sequence in call_sequences:
    temp_call_sequence = []
    for call in call_sequence:
        x = ""
        try:
            x = (call.func.value.value + "." + call.func.attr.value)
        except:
            pass
        try:
            x = (call.func.value.value.value + "." + call.func.value.attr.value + "." + call.func.attr.value)
        except:
            pass
        try:
            x = (call.func.value.value.value.value + "." + call.func.value.value.attr.value + "." + call.func.value.attr.value + "." + call.func.attr.value )
        except:
            pass
        try:
            x = (call.func.value.value.value.value.value + "." + call.func.value.value.value.attr.value + "." + call.func.value.value.attr.value + "." + call.func.value.attr.value + "." + call.func.attr.value )
        except:
            pass
        temp_call_sequence.append(utils.MethodCall(x, call))
    call_sequences_processed.append(temp_call_sequence) 

target_method_done = []

for target_method in method_invocations_processed:
    if(target_method.name not in target_method_done):
        print("~ " + target_method.name)
        valid_call_sequences = utils.search_call_sequence(target_method, call_sequences_processed)
        for valid_call_sequence in valid_call_sequences:
            utils.generate_usage_pattern(target_method, valid_call_sequence).print()
        target_method_done.append(target_method.name)
        print()
        print()
# Out:
# ~ tf.placeholder
# ========== Usage Pattern ==========
# Target Method: tf.placeholder
# Pre-Set: {tf.reshape}
# Post-Set: {tf.reshape, tf.argmax}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.reshape
# ========== Usage Pattern ==========
# Target Method: tf.reshape
# Pre-Set: {tf.placeholder}
# Post-Set: {tf.placeholder, tf.argmax}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.reshape
# Pre-Set: {}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.argmax
# ========== Usage Pattern ==========
# Target Method: tf.argmax
# Pre-Set: {tf.placeholder, tf.reshape}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.argmax
# Pre-Set: {tf.nn.softmax}
# Post-Set: {tf.reduce_mean, tf.nn.softmax_cross_entropy_with_logits, tf.train.GradientDescentOptimizer, tf.equal, tf.cast, tf.global_variables_initializer, tf.train.Saver, tf.Session}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.nn.softmax
# ========== Usage Pattern ==========
# Target Method: tf.nn.softmax
# Pre-Set: {}
# Post-Set: {tf.argmax, tf.reduce_mean, tf.nn.softmax_cross_entropy_with_logits, tf.train.GradientDescentOptimizer, tf.equal, tf.cast, tf.global_variables_initializer, tf.train.Saver, tf.Session}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.nn.softmax
# Pre-Set: {tf.transpose, tf.SparseTensor, tf.compat.v1.placeholder, tf.reduce_mean, tf.compat.v1.nn.ctc_loss, tf.nn.ctc_greedy_decoder, tf.nn.ctc_beam_search_decoder}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.reduce_mean
# ========== Usage Pattern ==========
# Target Method: tf.reduce_mean
# Pre-Set: {tf.nn.softmax, tf.argmax, tf.nn.softmax_cross_entropy_with_logits, tf.train.GradientDescentOptimizer, tf.equal}
# Post-Set: {tf.nn.softmax_cross_entropy_with_logits, tf.train.GradientDescentOptimizer, tf.equal, tf.cast, tf.global_variables_initializer, tf.train.Saver, tf.Session}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.reduce_mean
# Pre-Set: {tf.transpose, tf.SparseTensor, tf.compat.v1.placeholder}
# Post-Set: {tf.compat.v1.nn.ctc_loss, tf.compat.v1.placeholder, tf.nn.ctc_greedy_decoder, tf.nn.ctc_beam_search_decoder, tf.nn.softmax}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.nn.softmax_cross_entropy_with_logits
# ========== Usage Pattern ==========
# Target Method: tf.nn.softmax_cross_entropy_with_logits
# Pre-Set: {tf.nn.softmax, tf.argmax, tf.reduce_mean}
# Post-Set: {tf.train.GradientDescentOptimizer, tf.equal, tf.reduce_mean, tf.cast, tf.global_variables_initializer, tf.train.Saver, tf.Session}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.train.GradientDescentOptimizer
# ========== Usage Pattern ==========
# Target Method: tf.train.GradientDescentOptimizer
# Pre-Set: {tf.nn.softmax, tf.argmax, tf.reduce_mean, tf.nn.softmax_cross_entropy_with_logits}
# Post-Set: {tf.equal, tf.reduce_mean, tf.cast, tf.global_variables_initializer, tf.train.Saver, tf.Session}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.equal
# ========== Usage Pattern ==========
# Target Method: tf.equal
# Pre-Set: {tf.nn.softmax, tf.argmax, tf.reduce_mean, tf.nn.softmax_cross_entropy_with_logits, tf.train.GradientDescentOptimizer}
# Post-Set: {tf.reduce_mean, tf.cast, tf.global_variables_initializer, tf.train.Saver, tf.Session}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.cast
# ========== Usage Pattern ==========
# Target Method: tf.cast
# Pre-Set: {tf.nn.softmax, tf.argmax, tf.reduce_mean, tf.nn.softmax_cross_entropy_with_logits, tf.train.GradientDescentOptimizer, tf.equal}
# Post-Set: {tf.global_variables_initializer, tf.train.Saver, tf.Session}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.global_variables_initializer
# ========== Usage Pattern ==========
# Target Method: tf.global_variables_initializer
# Pre-Set: {tf.nn.softmax, tf.argmax, tf.reduce_mean, tf.nn.softmax_cross_entropy_with_logits, tf.train.GradientDescentOptimizer, tf.equal, tf.cast}
# Post-Set: {tf.train.Saver, tf.Session}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.train.Saver
# ========== Usage Pattern ==========
# Target Method: tf.train.Saver
# Pre-Set: {tf.nn.softmax, tf.argmax, tf.reduce_mean, tf.nn.softmax_cross_entropy_with_logits, tf.train.GradientDescentOptimizer, tf.equal, tf.cast, tf.global_variables_initializer}
# Post-Set: {tf.Session}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.Session
# ========== Usage Pattern ==========
# Target Method: tf.Session
# Pre-Set: {tf.nn.softmax, tf.argmax, tf.reduce_mean, tf.nn.softmax_cross_entropy_with_logits, tf.train.GradientDescentOptimizer, tf.equal, tf.cast, tf.global_variables_initializer, tf.train.Saver}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.Session
# Pre-Set: {tf.Graph, tf.GraphDef, tf.gfile.GFile, tf.import_graph_def}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.Variable
# ========== Usage Pattern ==========
# Target Method: tf.Variable
# Pre-Set: {}
# Post-Set: {tf.truncated_normal}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.Variable
# Pre-Set: {}
# Post-Set: {tf.constant}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.Variable
# Pre-Set: {tf.expand_dims}
# Post-Set: {tf.random.truncated_normal, tf.nn.conv2d, tf.compat.v1.layers.batch_normalization, tf.nn.relu, tf.nn.max_pool2d}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.Variable
# Pre-Set: {tf.squeeze, tf.compat.v1.nn.bidirectional_dynamic_rnn, tf.expand_dims, tf.concat}
# Post-Set: {tf.random.truncated_normal, tf.squeeze, tf.nn.atrous_conv2d}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.truncated_normal
# ========== Usage Pattern ==========
# Target Method: tf.truncated_normal
# Pre-Set: {tf.Variable}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.constant
# ========== Usage Pattern ==========
# Target Method: tf.constant
# Pre-Set: {tf.Variable}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.nn.conv2d
# ========== Usage Pattern ==========
# Target Method: tf.nn.conv2d
# Pre-Set: {}
# Post-Set: {tf.nn.max_pool, tf.nn.relu}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.nn.conv2d
# Pre-Set: {tf.expand_dims, tf.Variable, tf.random.truncated_normal}
# Post-Set: {tf.compat.v1.layers.batch_normalization, tf.nn.relu, tf.nn.max_pool2d}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.nn.max_pool
# ========== Usage Pattern ==========
# Target Method: tf.nn.max_pool
# Pre-Set: {tf.nn.conv2d}
# Post-Set: {tf.nn.relu}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.nn.relu
# ========== Usage Pattern ==========
# Target Method: tf.nn.relu
# Pre-Set: {tf.nn.conv2d, tf.nn.max_pool}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.nn.relu
# Pre-Set: {tf.matmul}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.nn.relu
# Pre-Set: {tf.expand_dims, tf.Variable, tf.random.truncated_normal, tf.nn.conv2d, tf.compat.v1.layers.batch_normalization}
# Post-Set: {tf.nn.max_pool2d}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.matmul
# ========== Usage Pattern ==========
# Target Method: tf.matmul
# Pre-Set: {}
# Post-Set: {tf.nn.relu}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.compat.v1.disable_eager_execution
# ========== Usage Pattern ==========
# Target Method: tf.compat.v1.disable_eager_execution
# Pre-Set: {}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.compat.v1.placeholder
# ========== Usage Pattern ==========
# Target Method: tf.compat.v1.placeholder
# Pre-Set: {}
# Post-Set: {tf.compat.v1.get_collection, tf.control_dependencies, tf.compat.v1.train.AdamOptimizer}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.compat.v1.placeholder
# Pre-Set: {tf.transpose, tf.SparseTensor, tf.reduce_mean, tf.compat.v1.nn.ctc_loss}
# Post-Set: {tf.reduce_mean, tf.compat.v1.nn.ctc_loss, tf.nn.ctc_greedy_decoder, tf.nn.ctc_beam_search_decoder, tf.nn.softmax}
# Accompany-Set: {tf.compat.v1.nn.ctc_loss}
# ===================================
#
#
# ~ tf.compat.v1.get_collection
# ========== Usage Pattern ==========
# Target Method: tf.compat.v1.get_collection
# Pre-Set: {tf.compat.v1.placeholder}
# Post-Set: {tf.control_dependencies, tf.compat.v1.train.AdamOptimizer}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.control_dependencies
# ========== Usage Pattern ==========
# Target Method: tf.control_dependencies
# Pre-Set: {tf.compat.v1.placeholder, tf.compat.v1.get_collection}
# Post-Set: {tf.compat.v1.train.AdamOptimizer}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.compat.v1.train.AdamOptimizer
# ========== Usage Pattern ==========
# Target Method: tf.compat.v1.train.AdamOptimizer
# Pre-Set: {tf.compat.v1.placeholder, tf.compat.v1.get_collection, tf.control_dependencies}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.expand_dims
# ========== Usage Pattern ==========
# Target Method: tf.expand_dims
# Pre-Set: {}
# Post-Set: {tf.Variable, tf.random.truncated_normal, tf.nn.conv2d, tf.compat.v1.layers.batch_normalization, tf.nn.relu, tf.nn.max_pool2d}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.expand_dims
# Pre-Set: {tf.squeeze, tf.compat.v1.nn.bidirectional_dynamic_rnn}
# Post-Set: {tf.concat, tf.Variable, tf.random.truncated_normal, tf.squeeze, tf.nn.atrous_conv2d}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.random.truncated_normal
# ========== Usage Pattern ==========
# Target Method: tf.random.truncated_normal
# Pre-Set: {tf.expand_dims, tf.Variable}
# Post-Set: {tf.nn.conv2d, tf.compat.v1.layers.batch_normalization, tf.nn.relu, tf.nn.max_pool2d}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.random.truncated_normal
# Pre-Set: {tf.squeeze, tf.compat.v1.nn.bidirectional_dynamic_rnn, tf.expand_dims, tf.concat, tf.Variable}
# Post-Set: {tf.squeeze, tf.nn.atrous_conv2d}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.compat.v1.layers.batch_normalization
# ========== Usage Pattern ==========
# Target Method: tf.compat.v1.layers.batch_normalization
# Pre-Set: {tf.expand_dims, tf.Variable, tf.random.truncated_normal, tf.nn.conv2d}
# Post-Set: {tf.nn.relu, tf.nn.max_pool2d}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.nn.max_pool2d
# ========== Usage Pattern ==========
# Target Method: tf.nn.max_pool2d
# Pre-Set: {tf.expand_dims, tf.Variable, tf.random.truncated_normal, tf.nn.conv2d, tf.compat.v1.layers.batch_normalization, tf.nn.relu}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.squeeze
# ========== Usage Pattern ==========
# Target Method: tf.squeeze
# Pre-Set: {tf.compat.v1.nn.bidirectional_dynamic_rnn, tf.expand_dims, tf.concat, tf.Variable, tf.random.truncated_normal}
# Post-Set: {tf.compat.v1.nn.bidirectional_dynamic_rnn, tf.expand_dims, tf.concat, tf.Variable, tf.random.truncated_normal, tf.nn.atrous_conv2d}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.compat.v1.nn.bidirectional_dynamic_rnn
# ========== Usage Pattern ==========
# Target Method: tf.compat.v1.nn.bidirectional_dynamic_rnn
# Pre-Set: {tf.squeeze}
# Post-Set: {tf.expand_dims, tf.concat, tf.Variable, tf.random.truncated_normal, tf.squeeze, tf.nn.atrous_conv2d}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.concat
# ========== Usage Pattern ==========
# Target Method: tf.concat
# Pre-Set: {tf.squeeze, tf.compat.v1.nn.bidirectional_dynamic_rnn, tf.expand_dims}
# Post-Set: {tf.Variable, tf.random.truncated_normal, tf.squeeze, tf.nn.atrous_conv2d}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.nn.atrous_conv2d
# ========== Usage Pattern ==========
# Target Method: tf.nn.atrous_conv2d
# Pre-Set: {tf.squeeze, tf.compat.v1.nn.bidirectional_dynamic_rnn, tf.expand_dims, tf.concat, tf.Variable, tf.random.truncated_normal}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.transpose
# ========== Usage Pattern ==========
# Target Method: tf.transpose
# Pre-Set: {}
# Post-Set: {tf.SparseTensor, tf.compat.v1.placeholder, tf.reduce_mean, tf.compat.v1.nn.ctc_loss, tf.nn.ctc_greedy_decoder, tf.nn.ctc_beam_search_decoder, tf.nn.softmax}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.SparseTensor
# ========== Usage Pattern ==========
# Target Method: tf.SparseTensor
# Pre-Set: {tf.transpose}
# Post-Set: {tf.compat.v1.placeholder, tf.reduce_mean, tf.compat.v1.nn.ctc_loss, tf.nn.ctc_greedy_decoder, tf.nn.ctc_beam_search_decoder, tf.nn.softmax}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.compat.v1.nn.ctc_loss
# ========== Usage Pattern ==========
# Target Method: tf.compat.v1.nn.ctc_loss
# Pre-Set: {tf.transpose, tf.SparseTensor, tf.compat.v1.placeholder, tf.reduce_mean}
# Post-Set: {tf.compat.v1.placeholder, tf.nn.ctc_greedy_decoder, tf.nn.ctc_beam_search_decoder, tf.nn.softmax}
# Accompany-Set: {tf.compat.v1.placeholder}
# ===================================
#
#
# ~ tf.nn.ctc_greedy_decoder
# ========== Usage Pattern ==========
# Target Method: tf.nn.ctc_greedy_decoder
# Pre-Set: {tf.transpose, tf.SparseTensor, tf.compat.v1.placeholder, tf.reduce_mean, tf.compat.v1.nn.ctc_loss}
# Post-Set: {tf.nn.ctc_beam_search_decoder, tf.nn.softmax}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.nn.ctc_beam_search_decoder
# ========== Usage Pattern ==========
# Target Method: tf.nn.ctc_beam_search_decoder
# Pre-Set: {tf.transpose, tf.SparseTensor, tf.compat.v1.placeholder, tf.reduce_mean, tf.compat.v1.nn.ctc_loss, tf.nn.ctc_greedy_decoder}
# Post-Set: {tf.nn.softmax}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.compat.v1.Session
# ========== Usage Pattern ==========
# Target Method: tf.compat.v1.Session
# Pre-Set: {}
# Post-Set: {tf.compat.v1.train.Saver, tf.train.latest_checkpoint, tf.compat.v1.global_variables_initializer}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.compat.v1.train.Saver
# ========== Usage Pattern ==========
# Target Method: tf.compat.v1.train.Saver
# Pre-Set: {tf.compat.v1.Session}
# Post-Set: {tf.train.latest_checkpoint, tf.compat.v1.global_variables_initializer}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.train.latest_checkpoint
# ========== Usage Pattern ==========
# Target Method: tf.train.latest_checkpoint
# Pre-Set: {tf.compat.v1.Session, tf.compat.v1.train.Saver}
# Post-Set: {tf.compat.v1.global_variables_initializer}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.compat.v1.global_variables_initializer
# ========== Usage Pattern ==========
# Target Method: tf.compat.v1.global_variables_initializer
# Pre-Set: {tf.compat.v1.Session, tf.compat.v1.train.Saver, tf.train.latest_checkpoint}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.keras.backend.mean
# ========== Usage Pattern ==========
# Target Method: tf.keras.backend.mean
# Pre-Set: {}
# Post-Set: {tf.keras.backend.square, tf.keras.backend.sum, tf.keras.backend.sqrt}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.keras.backend.square
# ========== Usage Pattern ==========
# Target Method: tf.keras.backend.square
# Pre-Set: {tf.keras.backend.mean, tf.keras.backend.sum, tf.keras.backend.sqrt}
# Post-Set: {tf.keras.backend.sum, tf.keras.backend.sqrt}
# Accompany-Set: {tf.keras.backend.sum}
# ===================================
#
#
# ~ tf.keras.backend.sum
# ========== Usage Pattern ==========
# Target Method: tf.keras.backend.sum
# Pre-Set: {tf.keras.backend.mean, tf.keras.backend.square, tf.keras.backend.sqrt}
# Post-Set: {tf.keras.backend.square, tf.keras.backend.sqrt}
# Accompany-Set: {tf.keras.backend.square}
# ===================================
#
#
# ~ tf.keras.backend.sqrt
# ========== Usage Pattern ==========
# Target Method: tf.keras.backend.sqrt
# Pre-Set: {tf.keras.backend.mean, tf.keras.backend.square, tf.keras.backend.sum}
# Post-Set: {tf.keras.backend.sum, tf.keras.backend.square}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.keras.models.Sequential
# ========== Usage Pattern ==========
# Target Method: tf.keras.models.Sequential
# Pre-Set: {}
# Post-Set: {tf.keras.layers.Conv2D, tf.keras.layers.Flatten, tf.keras.layers.Dense, tf.keras.layers.Dropout}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.keras.layers.Conv2D
# ========== Usage Pattern ==========
# Target Method: tf.keras.layers.Conv2D
# Pre-Set: {tf.keras.models.Sequential}
# Post-Set: {tf.keras.layers.Flatten, tf.keras.layers.Dense, tf.keras.layers.Dropout}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.keras.layers.Flatten
# ========== Usage Pattern ==========
# Target Method: tf.keras.layers.Flatten
# Pre-Set: {tf.keras.models.Sequential, tf.keras.layers.Conv2D}
# Post-Set: {tf.keras.layers.Dense, tf.keras.layers.Dropout}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.keras.layers.Dense
# ========== Usage Pattern ==========
# Target Method: tf.keras.layers.Dense
# Pre-Set: {tf.keras.models.Sequential, tf.keras.layers.Conv2D, tf.keras.layers.Flatten, tf.keras.layers.Dropout}
# Post-Set: {tf.keras.layers.Dropout}
# Accompany-Set: {tf.keras.layers.Dropout}
# ===================================
#
#
# ~ tf.keras.layers.Dropout
# ========== Usage Pattern ==========
# Target Method: tf.keras.layers.Dropout
# Pre-Set: {tf.keras.models.Sequential, tf.keras.layers.Conv2D, tf.keras.layers.Flatten, tf.keras.layers.Dense}
# Post-Set: {tf.keras.layers.Dense}
# Accompany-Set: {tf.keras.layers.Dense}
# ===================================
#
#
# ~ tf.Graph
# ========== Usage Pattern ==========
# Target Method: tf.Graph
# Pre-Set: {}
# Post-Set: {}
# Accompany-Set: {}
# ===================================
# ========== Usage Pattern ==========
# Target Method: tf.Graph
# Pre-Set: {}
# Post-Set: {tf.GraphDef, tf.gfile.GFile, tf.import_graph_def, tf.Session}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.GraphDef
# ========== Usage Pattern ==========
# Target Method: tf.GraphDef
# Pre-Set: {tf.Graph}
# Post-Set: {tf.gfile.GFile, tf.import_graph_def, tf.Session}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.gfile.GFile
# ========== Usage Pattern ==========
# Target Method: tf.gfile.GFile
# Pre-Set: {tf.Graph, tf.GraphDef}
# Post-Set: {tf.import_graph_def, tf.Session}
# Accompany-Set: {}
# ===================================
#
#
# ~ tf.import_graph_def
# ========== Usage Pattern ==========
# Target Method: tf.import_graph_def
# Pre-Set: {tf.Graph, tf.GraphDef, tf.gfile.GFile}
# Post-Set: {tf.Session}
# Accompany-Set: {}
# ===================================

# %%
target_method_done = []
usage_pattern_dict = {}

for target_method in method_invocations_processed:
    if(target_method.name not in target_method_done):
        usage_pattern_dict[target_method.name] = []
        valid_call_sequences = utils.search_call_sequence(target_method, call_sequences_processed)
        for valid_call_sequence in valid_call_sequences:
            temp_usage_pattern = utils.generate_usage_pattern(target_method, valid_call_sequence)
            usage_pattern_dict[target_method.name].append(temp_usage_pattern)
        target_method_done.append(target_method.name)

# %% [markdown]
# ### 4. Sequence Clusters

# %%
from pandas import *
for key in usage_pattern_dict:
    print("=================================================")
    print("Method Invocation: " + key)
    print()

    target_usage_pattern_list = usage_pattern_dict[key]

    if len(target_usage_pattern_list) == 1:
        print("Method Invocation contains only 1 usage pattern.")
        print("No clusters are generated. ")
    else:
        similarity_matrix = utils.generate_similarity_matrix(target_usage_pattern_list)
        print("Similarity Matrix: ")
        print(DataFrame(similarity_matrix))
        print()
        utils.generate_clusters(similarity_matrix, True)
# Out:
# =================================================
# Method Invocation: tf.placeholder
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.reshape
#
# Similarity Matrix:
#           0         1
# 0  1.000000  0.333333
# 1  0.333333  1.000000
# Labels:
# [0 1]
# =================================================
# Method Invocation: tf.argmax
#
# Similarity Matrix:
#           0         1
# 0  1.000000  0.333333
# 1  0.333333  1.000000
# Labels:
# [0 1]
# =================================================
# Method Invocation: tf.nn.softmax
#
# Similarity Matrix:
#           0         1
# 0  1.000000  0.333333
# 1  0.333333  1.000000
# Labels:
# [0 1]
# =================================================
# Method Invocation: tf.reduce_mean
#
# Similarity Matrix:
#           0         1
# 0  1.000000  0.333333
# 1  0.333333  1.000000
# Labels:
# [0 1]
# =================================================
# Method Invocation: tf.nn.softmax_cross_entropy_with_logits
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.train.GradientDescentOptimizer
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.equal
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.cast
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.global_variables_initializer
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.train.Saver
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.Session
#
# Similarity Matrix:
#           0         1
# 0  1.000000  0.666667
# 1  0.666667  1.000000
# Labels:
# [0 1]
# =================================================
# Method Invocation: tf.Variable
#
# Similarity Matrix:
#           0         1         2         3
# 0  1.000000  0.666667  0.333333  0.333333
# 1  0.666667  1.000000  0.333333  0.333333
# 2  0.333333  0.333333  1.000000  0.464286
# 3  0.333333  0.333333  0.464286  1.000000
# Labels:
# [0 0 1 1]
# =================================================
# Method Invocation: tf.truncated_normal
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.constant
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.nn.conv2d
#
# Similarity Matrix:
#           0         1
# 0  1.000000  0.416667
# 1  0.416667  1.000000
# Labels:
# [0 1]
# =================================================
# Method Invocation: tf.nn.max_pool
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.nn.relu
#
# Similarity Matrix:
#           0         1         2
# 0  1.000000  0.666667  0.388889
# 1  0.666667  1.000000  0.333333
# 2  0.388889  0.333333  1.000000
# Labels:
# [-1 -1 -1]
# =================================================
# Method Invocation: tf.matmul
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.compat.v1.disable_eager_execution
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.compat.v1.placeholder
#
# Similarity Matrix:
#      0    1
# 0  1.0  0.0
# 1  0.0  1.0
# Labels:
# [0 1]
# =================================================
# Method Invocation: tf.compat.v1.get_collection
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.control_dependencies
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.compat.v1.train.AdamOptimizer
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.expand_dims
#
# Similarity Matrix:
#           0         1
# 0  1.000000  0.407407
# 1  0.407407  1.000000
# Labels:
# [0 1]
# =================================================
# Method Invocation: tf.random.truncated_normal
#
# Similarity Matrix:
#           0         1
# 0  1.000000  0.466667
# 1  0.466667  1.000000
# Labels:
# [0 1]
# =================================================
# Method Invocation: tf.compat.v1.layers.batch_normalization
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.nn.max_pool2d
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.squeeze
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.compat.v1.nn.bidirectional_dynamic_rnn
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.concat
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.nn.atrous_conv2d
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.transpose
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.SparseTensor
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.compat.v1.nn.ctc_loss
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.nn.ctc_greedy_decoder
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.nn.ctc_beam_search_decoder
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.compat.v1.Session
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.compat.v1.train.Saver
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.train.latest_checkpoint
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.compat.v1.global_variables_initializer
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.keras.backend.mean
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.keras.backend.square
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.keras.backend.sum
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.keras.backend.sqrt
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.keras.models.Sequential
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.keras.layers.Conv2D
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.keras.layers.Flatten
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.keras.layers.Dense
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.keras.layers.Dropout
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.Graph
#
# Similarity Matrix:
#           0         1
# 0  1.000000  0.666667
# 1  0.666667  1.000000
# Labels:
# [0 1]
# =================================================
# Method Invocation: tf.GraphDef
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.gfile.GFile
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.
# =================================================
# Method Invocation: tf.import_graph_def
#
# Method Invocation contains only 1 usage pattern.
# No clusters are generated.

# %%
from pandas import *
for key in usage_pattern_dict:
    if(key == "tf.nn.relu"):
        print("=================================================")
        print("Method Invocation: " + key)
        print()

        target_usage_pattern_list = usage_pattern_dict[key]

        if len(target_usage_pattern_list) == 1:
            print("Method Invocation contains only 1 usage pattern.")
            print("No clusters are generated. ")
        else:
            similarity_matrix = utils.generate_similarity_matrix(target_usage_pattern_list)
            print("Similarity Matrix: ")
            print(DataFrame(similarity_matrix))
            print()
            utils.generate_clusters(similarity_matrix, True)
# Out:
# =================================================
# Method Invocation: tf.nn.relu
#
# Similarity Matrix:
#           0         1         2
# 0  1.000000  0.666667  0.388889
# 1  0.666667  1.000000  0.333333
# 2  0.388889  0.333333  1.000000
# Labels:
# [0 0 1]
